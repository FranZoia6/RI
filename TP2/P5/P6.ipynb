# %%
import re

def tokenizador(text):
    text = text.lower()
    intab = "áéíóú"
    outtab = "aeiou"
    str = text
    trantab = str.maketrans(intab, outtab)
    normalizado = str.translate(trantab)
    normalizado = re.sub(r'[^a-z0-9 ]','', normalizado)
    tokens = normalizado.split(" ")
    if "" in tokens:
        while "" in tokens:
            tokens.remove("")
    return tokens

# %%
import math
def get_score(index,termsDoc, queri):
    score = {}
    cantDoc = len(index)

    for q in queri:
        idf = math.log(cantDoc / termsDoc[q]["df"])
        for path,terms in index.items():
            if q in terms:
                tf = terms[q] / len(terms)
                if path in score:
                    score[path] +=  tf*idf
                else:
                    score[path] = tf*idf 
    return score

# %%
def contadorTerms(terms, tokens):
    for token in tokens:
        if token in terms:
            terms[token] += 1
        elif len(token)>2 and len(token)<20:
            terms[token] = 1
    return terms

# %%
import nltk
from nltk.corpus import stopwords
def remove_sportsworld(terms):
    dic = {}
    stopsSp = set(stopwords.words('spanish'))
    stopsEn = set(stopwords.words('english'))
    for term in terms:
        if term not in stopsSp and term not in stopsEn:
            dic[term] = terms[term]
    return dic

# %%
import os

root_dir = "wiki-small/"


def enumerate_html_files(directory):
    document_id = 1
    index = {}
    terms = {}
    for root, _, files in os.walk(directory):
        for file in files:
            dic = {}
            tokens = {}
            file_path = os.path.join(root, file)
            with open(file_path, 'r', encoding='utf-8') as html_file:
                termsAux = {}
                content = html_file.read()
                tokens =tokenizador(content)
                dic = contadorTerms(dic,tokens)
                termsAux = contadorTerms(termsAux,tokens)
                dic = remove_sportsworld(dic)
                index[file_path] = dic
                for term, aux in termsAux.items():
                    if term in terms:
                        terms[term]["cf"] += aux
                        terms[term]["df"] += 1
                    else:
                        terms[term] = {"cf": aux, "df": 1}
    return index, terms

index,terms = enumerate_html_files(root_dir)

# %%
score=get_score(index,terms, ['software'])

# %%
sorted_terms = sorted(score.items(), key=lambda item: item[1], reverse=True)
sorted_terms
# Out:
# [('wiki-small/en/articles/j/f/i/JFin_1830.html', 0.17322095022294667),
#  ('wiki-small/en/articles/r/o/x/ROX_Desktop_b4f8.html', 0.16316985804951645),
#  ('wiki-small/en/articles/a/u/t/Autodesk_Developer_Network_cf4f.html',
#   0.1317520592946406),
#  ('wiki-small/en/articles/s/t/e/Stellarium.html', 0.12949988734088605),
#  ('wiki-small/en/articles/k/a/o/KAOS_(software_development)_665f.html',
#   0.07039926761484411),
#  ('wiki-small/en/articles/m/i/k/MiKTeX_fd58.html', 0.044166277366786404),
#  ('wiki-small/en/articles/p/v/s/Pvserver.html', 0.04223956056890646),
#  ('wiki-small/en/articles/e/l/e/Electronic_data_capture.html',
#   0.04188814991525499),
#  ('wiki-small/en/articles/r/e/a/Reactor_(Havok)_5dbb.html',
#   0.03861162285133168),
#  ('wiki-small/en/articles/p/p/3/PP3_444f.html', 0.03516030460763722),
#  ('wiki-small/en/articles/m/i/c/Microtuner.html', 0.03458073914707177),
#  ('wiki-small/en/articles/h/p/i/Hping.html', 0.03321210831011643),
#  ('wiki-small/en/articles/o/p/e/OpenOffice.org_Impress_fe3f.html',
#   0.032972859330803204),
#  ('wiki-small/en/articles/s/o/f/SoftRAM_b9df.html', 0.032779658983161784),
#  ('wiki-small/en/articles/c/d/r/CDRWIN_b7e8.html', 0.031967972189293016),
#  ('wiki-small/en/articles/l/i/n/LinuxSysInfo_6788.html', 0.03062625072879349),
#  ('wiki-small/en/articles/j/o/h/John_Bridges_c39b.html', 0.0299699739274622),
#  ('wiki-small/en/articles/k/u/r/Kure.html', 0.02913747465169936),
#  ('wiki-small/en/articles/d/e/l/Delphine_(disambiguation).html',
#   0.02873833116331992),
#  ('wiki-small/en/articles/a/t/t/Attribute_clash.html', 0.027786730793673567),
#  ('wiki-small/en/articles/z/e/n/Zend_Framework_a5ef.html',
#   0.027270728364821688),
#  ('wiki-small/en/articles/p/r/e/PrefixNE_f5f9.html', 0.02698261318228108),
#  ('wiki-small/en/articles/n/+/_/N+.html', 0.025860069952817925),
#  ('wiki-small/en/articles/t/e/a/Teamlinux.html', 0.025275881625570533),
#  ('wiki-small/en/articles/u/n/r/Unreal.html', 0.021790056058050997),
#  ('wiki-small/en/articles/l/e/a/Leaky_abstraction.html', 0.02155374837248994),
#  ('wiki-small/en/articles/b/r/l/BRL-CAD_2b85.html', 0.020750723787560377),
#  ('wiki-small/en/articles/m/i/c/Microsoft_Dynamics_AX_71bb.html',
#   0.018163620562098304),
#  ('wiki-small/en/articles/l/y/n/LynxOS_dd39.html', 0.01712569938712126),
#  ('wiki-small/en/articles/i/n/t/Interstellar_Flames_2_bbdd.html',
#   0.0160758480836962),
#  ('wiki-small/en/articles/r/h/a/Rhapsody_(online_music_service).html',
#   0.01586312419601024),
#  ('wiki-small/en/articles/l/a/d/Ladder-DES_e9e6.html', 0.0156559565292713),
#  ('wiki-small/en/articles/f/o/r/Fortress_(software).html',
#   0.014826135511818758),
#  ('wiki-small/en/articles/w/b/t/WBT_7a58.html', 0.014722092455595468),
#  ('wiki-small/en/articles/t/e/r/Teresa_Wentzler_46e8.html',
#   0.014174987668394286),
#  ('wiki-small/en/articles/x/i/t/Xito.html', 0.013985987832815695),
#  ('wiki-small/en/articles/a/r/i/Ariadne_(disambiguation).html',
#   0.013893365396836783),
#  ('wiki-small/en/articles/p/i/r/Piriform.html', 0.01380196167712075),
#  ('wiki-small/en/articles/n/e/u/Neuros_Technology_a3a7.html',
#   0.013711752777270289),
#  ('wiki-small/en/articles/y/a/s/Yass_(software).html', 0.013405100159248269),
#  ('wiki-small/en/articles/s/k/y/Sky_&_Telescope_0718.html',
#   0.013362408757467225),
#  ('wiki-small/en/articles/p/i/r/Pirates@home.html', 0.012792062042209477),
#  ('wiki-small/en/articles/s/u/r/Battleship~_Surface_Thunder_eea1.html',
#   0.012714534393468813),
#  ('wiki-small/en/articles/e/r/p/ERP_modeling_5a2f.html', 0.012676121902854104),
#  ('wiki-small/en/articles/g/o/g/GoGo_board_8d64.html', 0.012676121902854104),
#  ('wiki-small/en/articles/m/a/r/Marquee.html', 0.012304388122711755),
#  ('wiki-small/en/articles/r/d/m/RDM_0067.html', 0.011886108639786709),
#  ('wiki-small/en/articles/c/h/e/Cheetah_Marketing_f331.html',
#   0.011654989860679746),
#  ('wiki-small/en/articles/t/e/l/Teledyne_Brown_Engineering_382e.html',
#   0.011495332465327968),
#  ('wiki-small/en/articles/s/a/b/Sabayon_Linux_00f3.html',
#   0.011263882818375056),
#  ('wiki-small/en/articles/r/e/g/Regi-Stick_259a.html', 0.011248783779744526),
#  ('wiki-small/en/articles/f/o/l/Folded_Man_6c7e.html', 0.011099990343504519),
#  ('wiki-small/en/articles/h/e/r/Hercules_(corporation).html',
#   0.01098376007812751),
#  ('wiki-small/en/articles/s/c/r/Screenwriting_guru.html',
#   0.010786108868495393),
#  ('wiki-small/en/articles/m/å/r/Mårten_Mickos_1268.html',
#   0.010786108868495393),
#  ('wiki-small/en/articles/d/a/r/Top_Gear~_Dare_Devil_fe12.html',
#   0.010676326589935645),
#  ('wiki-small/en/articles/h/i/m/Himakuntla.html', 0.010385634529318585),
#  ('wiki-small/en/articles/d/r/i/Driver.html', 0.010334473768090414),
#  ('wiki-small/en/articles/r/o/b/Roblimo.html', 0.010183971722924049),
#  ('wiki-small/en/articles/p/r/i/Prince_XML_03cf.html', 0.008965376815907497),
#  ('wiki-small/en/articles/i/g/o/IGo_d87c.html', 0.00883325547335728),
#  ("wiki-small/en/articles/b/a/r/Bart_Simpson's_Escape_from_Camp_Deadly_55a9.html",
#   0.008814698213959471),
#  ('wiki-small/en/articles/f/o/a/FOAF_(software)_ac27.html',
#   0.008669000722819646),
#  ('wiki-small/en/articles/a/l/i/Aliens_versus_Predator_2_7706.html',
#   0.00835399970103476),
#  ('wiki-small/en/articles/n/o/t/Notepad.html', 0.008139275169436874),
#  ('wiki-small/en/articles/l/i/s/List_of_Java_virtual_machines_dcf2.html',
#   0.008099992953368162),
#  ('wiki-small/en/articles/l/o/u/Lout.html', 0.007886835244069001),
#  ('wiki-small/en/articles/h/e/r/Heraldo_Filipino_f40a.html',
#   0.007649583135541856),
#  ('wiki-small/en/articles/c/b/_/CB_834c.html', 0.00753284802485585),
#  ('wiki-small/en/articles/i/p/v/IPv6_fdb7.html', 0.007455217394891095),
#  ('wiki-small/en/articles/l/a/w/Lawson.html', 0.007399993562336346),
#  ('wiki-small/en/articles/m/e/g/Mega_Bloks_c0bd.html', 0.005647101412980765),
#  ('wiki-small/en/articles/l/a/n/Languages_of_the_Democratic_Republic_of_the_Congo_a372.html',
#   0.005639511222909554),
#  ('wiki-small/en/articles/s/s/x/SSX_Blur_8aed.html', 0.005528058431942963),
#  ('wiki-small/en/articles/i/n/t/Intellivoice.html', 0.005442018611990542),
#  ('wiki-small/en/articles/s/o/t/Sota_Fujimori_cd94.html',
#   0.005379226089544498),
#  ('wiki-small/en/articles/t/w/i/Summon_Night~_Twin_Age_90e9.html',
#   0.005311134620056593),
#  ('wiki-small/en/articles/n/u/s/NUS_School_of_Computing_e6f0.html',
#   0.004828304200051448),
#  ('wiki-small/en/articles/n/e/w/Trauma_Center~_New_Blood_6e82.html',
#   0.004610765219609569),
#  ('wiki-small/en/articles/c/u/l/Culture_of_Denmark_9881.html',
#   0.0044636131381326685),
#  ('wiki-small/en/articles/h/e/a/Heart_of_Darkness_(video_game)_fcc7.html',
#   0.004334500361409823),
#  ('wiki-small/en/articles/e/n/d/Endless_Wire_(The_Who_album)_997b.html',
#   0.003958298443249725),
#  ('wiki-small/en/articles/n/o/r/North_Canton,_Ohio_f2c4.html',
#   0.0038670934099951228),
#  ('wiki-small/en/articles/b/r/a/Brave_Fencer_Musashi_22c6.html',
#   0.003262672122740831),
#  ('wiki-small/en/articles/b/u/d/Dragon_Ball_Z~_Budokai_2_ded8.html',
#   0.0031834570180915844),
#  ('wiki-small/en/articles/c/a/l/California_Institute_of_the_Arts_ca76.html',
#   0.0029568684635973984),
#  ('wiki-small/en/articles/j/a/m/James_Ossuary_2465.html',
#   0.0028996519349306898),
#  ('wiki-small/en/articles/t/h/e/Scarface~_The_World_Is_Yours_10f0.html',
#   0.00263224363227397),
#  ('wiki-small/en/articles/c/l/a/Class_(computer_science).html',
#   0.00256623629959921),
#  ('wiki-small/en/articles/e/m/p/Empires_(mod).html', 0.0024451027679747717),
#  ('wiki-small/en/articles/a/q/u/Aqua_(user_interface).html',
#   0.002419721078341816)]
